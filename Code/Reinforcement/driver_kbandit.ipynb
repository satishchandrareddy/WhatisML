# %% [markdown]
# # **Kbandid Demo**

# %%
# run this cell if you're using Google Colab
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
  import sys
  import os
  # !git clone https://github.com/satishchandrareddy/WhatisML.git
  code_location = "/content/WhatisML/Code/Reinforcement"
  sys.path.append(os.path.abspath(code_location))
# Out:
# Cloning into 'WhatisML'...
# remote: Enumerating objects: 233, done.
# remote: Counting objects: 100% (233/233), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 233 (delta 103), reused 205 (delta 75), pack-reused 0
# Receiving objects: 100% (233/233), 20.44 MiB | 20.07 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %% [markdown]
# ## **Import Libraries**

# %%
from IPython.display import HTML
import kbandit
import matplotlib.pyplot as plt

# %% [markdown]
# ## **1. Create Model**

# %%
list_epsilon = [0,0.1]
k = 10
nsim = 1000
nstep = 150
seed = 10

# %% [markdown]
# ## **2. Simulate**

# %%
list_na, list_reward = kbandit.run(list_epsilon,k,nsim,nstep,seed)
# Out:
# Epsilon: 0
# Epsilon: 0.1

# %% [markdown]
# ## **3. Plot results**

# %%
# plot proportion optimal as a function of time
kbandit.plot_results_optimal(list_epsilon,list_na)

# %%
# plot average reward
kbandit.plot_results_reward(list_epsilon,list_reward)

# %%
# animation of bar charts
ani = kbandit.plot_results_bar_animation(list_epsilon[0:2],list_na[0:2])
vid = HTML(ani.to_html5_video())
vid
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
